# %% [markdown]
# # Assignment 7: Expectation Maximization
#
# MIDS W281: Computer Vision

# %% [markdown]
# ## Recommended Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from skimage.color import rgb2gray
import skimage.feature
from matplotlib.patches import Circle

# %% [markdown]
# ![Hybrid Teaser](https://raw.githubusercontent.com/W281/fileRepository/main/Assignments/output.gif)

# %% [markdown]
#  ### Overview
# In tasks with noisy input data, it is often necessary to estimate parameters using an iterative approach. To illustrate this, we have provided you a realistic (but very simple) optimization problem.
#
# You are tasked with writing the software for a parts inspection system. The input to this system is a color image of a circular part. Your task is to locate and fit a circle (center and radius) to the part, and then determine whether the size of the part (its radius) is within a specified tolerance. You will use the expectation/maximization (EM) algorithm to simultaneously locate the boundary of the circular part, fit a circle to the part, and estimate the goodness of the fit.
#
# ### Description
#
# 1. To begin, your system should load a color (RGB) image, convert the image to grayscale, and extract the salient edges in the image. You can use the Canny edge detector from Python's OpenCV library to find the edges. This function will return a binary image with a value of 1 at a pixel location corresponding to a salient edge and 0 otherwise. Note that you will need to play around with the size of the filter to get a useful output. You might need to exclude the edges of the image and then extract the x- and y-coordinates of all pixels with an edge value equal to 1 (see numpy's `argwhere`). It is from these coordinates that we will find and fit a circle.
#
# 2. The coordinates of each edge pixel correspond to one of two models:
#     (1) a circle with center $(c_x,c_y)$ and radius $(r)$; or
#     (2) an "outlier" model.
#     The conditional probability of belonging to model 1 will be modeled as a Gaussian distribution $(g(d) = exp(-d^2/σ)$ and will depend on the distance, $d$, of each point to the circle. The conditional probability of belonging to model 2 will be modeled as a uniform distribution and fixed to be 1/10.
#     **HINT: the async mentioned two kinds of conditional probabilities, figure out which kind of conditional probability was just provided for models 1 and 2, and how this kind of conditional probability is used throughout the entire EM process**
#
# 3. You should begin your EM iterations by initializing $(c_x,c_y)$ to be the image center, $r=190$ pixels, and $σ=128$.
#
# 4. In the E-step, the residual error for model 1 is based on the shortest distance, $d$, between a point $(x,y)$ and the current estimate of the circle with center $(c_x,c_y)$ and radius, $r$. This distance is:
#     $$d=\left\lvert \sqrt{ (x-c_x)^2 + (y-c_y)^2} - r \right\rvert$$
#
# 5. In the M-step, you will use weighted total least-squares to re-estimate the paramters of the circle. First, implement the total least-squares estimator described in Section 2 of the gander_golub_strebel.pdf paper in the Assignment 7 GitHub repo. The weights of weighted total least-squares estimator are computed in the E-step. Incorporate this weighting into your total least-squares estimator.
#
# 6. After performing the E- and M-step, update the value of $σ$.
#     **HINT: when updating sigma, you can assume the residuals for the noise model (model 2) is 0, but you should still be able to calculate the conditional probability that was not given above for model 2 if you understand the concepts**
#
# 7. Repeatedly perform the E- and M-steps until the difference between subsequent estimates of the circle center and radius are each less than 0.1 pixels.
#
# 8. As shown in the sample output above, on each EM iteration you should display two images:
#     (1) the current circle superimposed on top of the original RGB image;
#     (2) the current probability of each pixel location belonging to model 1 visualized as an image.
#
# 9. Show your final fitting results on the five images provided in the "discs" directory.
# **If your solution is similar to ours, it might fail on the image disc4.jpg. If so, fix this failure by choosing a better initial value for $(c_x, c_y)$.**

# %% [markdown]
# ### Deliverables:
#
# - Python code to perform the above EM algorithm.
# - Plots showing the steps for for EM for each of the image.
# - Plot showing the final fitting results, i.e. the circle super-imposed on the RGB disc image.
#
# To see a sample output of the convergence process, see images/SampleOutput.mov.  Your convegence process does not need to match it exactly, but it should be similar.

# %% [markdown]
# ### Create your Function to execute the above steps

# %%
def find_EM(fileName):
    # write a function that takes the the filename of an image,
    # converts the image to grayscale,
    # calculates the edges using the Canny edge detector,
    # runs EM process and plots/displays 
    # each step of the process.
    # function should NOT return anything.

    # Load the image
    rgb_im = plt.imread(fileName)

    # convert to grayscale
    ## TODO im = ??? (convert to grayscale)
    im = rgb2gray(rgb_im)

    # Find edge cordinate

    ## TODO use skimage.feature.canny to find the outer edges of the discs
    ## NOTE: experiment with the parameters to find a reasonable amount of points (<10k) that has a good signal to noise ratio
    ## TODO edgeIm = ???
    edgeIm = skimage.feature.canny(im, sigma=3, low_threshold=0.1, high_threshold=0.3)

    ## find the x-y cordinates with edge == 1 **hint: use np.argwhere
    # TODO cord = ???
    cord = np.argwhere(edgeIm)

    ## create X and Y arrays for the coordinates
    Y = cord[:, 0]
    X = cord[:, 1]

    # Print the number of points
    noOfPoints = len(cord)
    print(f'Number of Points: {noOfPoints}')

    # display the image and plot the edge coordinates
    ## display the image 
    plt.imshow(im, cmap='gray') 
    plt.plot(X, Y, 'r.')
    plt.title('Detected Edges')
    plt.show()

    # Expectation/Maximization
    ## intialize new center (cx, cy)/2 and radius to 190
    new_cx = im.shape[1] / 2.0 # 210
    new_cy = im.shape[0] / 2.0 # 320
    new_r = 190

    prev_cx = 0
    prev_cy = 0
    prev_r = 0

    ## initial sigma
    sigma = 128

    # create empty arrays for expectation and d that correspond to the number of coordinates previously calculated 
    expectation = np.zeros((noOfPoints,))
    d = np.zeros((noOfPoints,))

    # repeat optimization till the difference is greater than 0.1
    # expectation step
    # compute the expectation of each point given prev parameters
    # after each step, display the images with circle and expectation weights 
    
    while((np.abs(prev_cx - new_cx) > 0.1) or (np.abs(prev_cy - new_cy) > 0.1) or (np.abs(prev_r - new_r) > 0.1)):
        
        prev_cx = new_cx
        prev_cy = new_cy
        prev_r = new_r

        ## expectation step
        ### compute the expectation of each point given prev parameters
        for i in range(noOfPoints):

            #TODO d[i] = ??
            d[i] = np.sqrt((X[i] - prev_cx) ** 2 + (Y[i] - prev_cy) ** 2) - prev_r

            #TODO p_model1 = ??
            # p_model1 is the probability of the point being on the disc
            # using Gaussian distribution
            p_model1 = np.exp(-d[i] ** 2 / (2 * sigma ** 2))

            #TODO p_model2 = ??
            # p_model2 is the probability of the point being outside the disc
            # using Uniform distribution
            p_model2 = 1 / (2 * np.pi * prev_r * sigma)

            #TODO expectation[i] = ??
            expectation[i] = p_model1 / (p_model1 + p_model2)


        exIm = np.zeros((im.shape[0], im.shape[1]))

        #for i in range(len(cord)):
        for i in range(noOfPoints):
            r,c = np.unravel_index(cord[i], (im.shape[0], im.shape[1]))[1]
            exIm[r,c] = expectation[i]

        ## display the images with circle and expectation weights
        fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(10,5))
        ax[0].imshow(rgb_im)
        
        circ = Circle( (prev_cx, prev_cy), radius=prev_r, fill = False )
        ax[0].add_patch(circ)
        ax[1].imshow(exIm)
        ax[0].set_title(f'r = {np.around(prev_r, 2)}, cx = {np.around(prev_cx, 2)}, cy = {np.around(prev_cy, 2)}')
        ax[1].set_title('Expectation Weights')
        ax[0].set_xlabel('X-axis')
        ax[0].set_ylabel('Y-axis')
        ax[1].set_xlabel('X-axis')
        ax[1].set_ylabel('Y-axis')
        ax[0].set_xlim([0, im.shape[1]])
        ax[0].set_ylim([im.shape[0], 0])
        ax[1].set_xlim([0, im.shape[1]])
        ax[1].set_ylim([im.shape[0], 0])
        ax[0].set_aspect('equal')
        ax[1].set_aspect('equal')
        ax[0].set_title('Expectation Step')
        plt.tight_layout()
        plt.show()

        # maximization step
        # ||WBu|| minimization

        M = np.zeros((noOfPoints, 4))  # Matrix to hold the coordinates with weights
        for i in range(noOfPoints):
            M[i, 0] = X[i] * expectation[i]
            M[i, 1] = Y[i] * expectation[i]
            M[i, 2] = expectation[i]
            M[i, 3] = 1
        
        #TODO W = ??
        W = np.diag(np.sqrt(expectation))

        WM = W @ M


        # use SVD to solve for u in ||WBu||
        # use the vector with minimum eigen value
        U, S, Vt = np.linalg.svd(WM)
        u = Vt[-1, :]

        # update center and radius
        #TODO new_cx = ??
        new_cx = u[0] / u[2]
        #TODO new_cy = ??
        new_cy = u[1] / u[2]
        #TODO new_r = ??
        new_r = np.sqrt(new_cx ** 2 + new_cy ** 2 - 2 * u[3]) / u[2]

        # update sigma
        #TODO sigma = ??
        sigma = np.sqrt(np.sum((expectation - np.mean(expectation)) ** 2) / np.sum(expectation))
        print(f'New Center: ({new_cx}, {new_cy}), New Radius: {new_r}, New Sigma: {sigma}')
        print(f'Previous Center: ({prev_cx}, {prev_cy}), Previous Radius: {prev_r}, Previous Sigma: {sigma}')
        print(f'Expectation: {expectation.mean()}')
        print(f'Norm of u: {np.linalg.norm(u)}')
        print(f'Norm of W: {np.linalg.norm(W)}')
        print(f'Norm of WM: {np.linalg.norm(WM)}')

def plot_save_sphere(X, Y, Z, C, out_file):
    # create a 3D plot
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    
    # plot the sphere
    ax.plot_surface(X, Y, Z, facecolors=C, rstride=1, cstride=1, linewidth=0, antialiased=False)

# %% [markdown]
# ### Run your function for all disc images

# %%
for image in os.listdir('discs'):
    print(f'Image: {image}')
    find_EM('discs/' + image)
# Out:
# Image: disc2.jpg
# Number of Points: 2330
# /var/folders/0y/g2tm105x5fj4b33ds4k_rtb00000gn/T/ipykernel_24914/3612838607.py:148: RuntimeWarning: invalid value encountered in sqrt
#   new_r = np.sqrt(new_cx ** 2 + new_cy ** 2 - 2 * u[3]) / u[2]
# New Center: (-2.8608278223313405e-09, 1.6204244029409073e-09), New Radius: nan, New Sigma: 2.1003326627920234e-06
# Previous Center: (233.0, 233.0), Previous Radius: 190, Previous Sigma: 2.1003326627920234e-06
# Expectation: 0.9999918472778424
# Norm of u: 1.0
# Norm of W: 48.26987677793858
# Norm of WM: 18086.845641069594
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 for image in os.listdir('discs'):
#       2     print(f'Image: {image}')
# ----> 3     find_EM('discs/' + image)
#
# Cell In[3], line 139, in find_EM(fileName)
#     134 WM = W @ M
#     137 # use SVD to solve for u in ||WBu||
#     138 # use the vector with minimum eigen value
# --> 139 U, S, Vt = np.linalg.svd(WM)
#     140 u = Vt[-1, :]
#     142 # update center and radius
#     143 #TODO new_cx = ??
#
# File /opt/anaconda3/envs/cv_env/lib/python3.10/site-packages/numpy/linalg/_linalg.py:1812, in svd(a, full_matrices, compute_uv, hermitian)
#    1808 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#    1809 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1810               invalid='call', over='ignore', divide='ignore',
#    1811               under='ignore'):
# -> 1812     u, s, vh = gufunc(a, signature=signature)
#    1813 u = u.astype(result_t, copy=False)
#    1814 s = s.astype(_realType(result_t), copy=False)
#
# File /opt/anaconda3/envs/cv_env/lib/python3.10/site-packages/numpy/linalg/_linalg.py:113, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     112 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 113     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge
